# %% [markdown]
# # Day 1: Exploratory Data Analysis
#
# This notebook regenerates the Day 1 report and charts from the processed Amazon All Beauty dataset.

# %%
from recommender.analysis.eda import main

main()
